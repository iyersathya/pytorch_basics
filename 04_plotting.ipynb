# %% [markdown]
# ## Basics plotting notes from book Python for Data Analysis
# To get a detailed notes an tutorial please read this book and refer to https://github.com/wesm/pydata-book

# %%
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
#Sets up integration, so that multiple plot windows can be drawn inside notebook.
# %matplotlib inline

# %%
# Plot with matplotlib
data = np.arange(10)
plt.plot(data)

# %%
# draw different types of plots.
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50).cumsum(),'k--')
_ = ax1.hist(np.random.randn(50),bins=10,alpha=0.3)
ax2.scatter(np.random.randn(50),np.random.randn(50))
